# %%
'''Q1. Explain why we have to use the Exception class while creating a Custom Exception.

Ans-In object-oriented programming, an exception is a way to handle and indicate errors and 
abnormal conditions that may occur during the execution of a program.
When a program encounters an error, it can throw an exception that contains information about 
the error and its context. By catching and handling these exceptions, we can gracefully handle 
errors and prevent the program from crashing.
To create a custom exception in python, we need to create a new class that extends the Exception
class or one of its subclasses. The reason we extend the Exception class is that it provides a 
standardized way to handle and propagate exceptions.
By extending the Exception class, our custom exception class inherits all the methods and 
properties of the Exception class, including the ability to set and retrieve the exception 
message, stack trace, and other relevant information.
Furthermore, extending the Exception class ensures that our custom exception is compatible
with other exception handling mechanisms, such as the try-catch block and the throws keyword, 
making it easier to integrate our custom exception into our codebase.

Q2. Write a python program to print Python Exception Hierarchy.

Ans-def print_exception_hierarchy(exception_class, indent=0):
    print(' ' * indent + exception_class.__name__)
    for subclass in exception_class.__subclasses__():
        print_exception_hierarchy(subclass, indent + 2)

print_exception_hierarchy(BaseException)

Q3.What errors are defined in the ArithmeticError class? Explain any two with an example.

Ans-The ArithmeticError is a built-in class in Python that serves as a base class for exceptions
that occur during arithmetic operations. This class is a subclass of the Exception class and a 
superclass of several other error classes, such as ZeroDivisionError, OverflowError, 
FloatingPointError, and ValueError.
Here are two examples of errors that are defined in the ArithmeticError class:
1)ZeroDivisionError: This error occurs when we try to divide a number by zero. For example:
x = 10
y = 0
z = x / y  # ZeroDivisionError: division by zero
2)OverflowError: This error occurs when we try to perform an arithmetic operation that results
in a number that is too large to be represented. For example:
x = 2 ** 1000
y = 10
z = x * y  # OverflowError: int too large to convert to float

Q4.Why LookupError class is used? Explain with an example KeyError and IndexError.

Ans-The LookupError class is a built-in class in Python that serves as the base class for
exceptions that occur when a key or index is not found in a mapping or sequence. This class is
a superclass of several other error classes, such as KeyError and IndexError.
Here are two examples of errors that are defined in the LookupError class:
1)KeyError: This error occurs when we try to access a non-existent key in a dictionary. For example:
d = {'a': 1, 'b': 2, 'c': 3}
print(d['d'])  # KeyError: 'd'
2)IndexError: This error occurs when we try to access an index that is out of range in a 
sequence, such as a list or tuple. For example:
a = [1, 2, 3]
print(a[3])  # IndexError: list index out of range

Q5.Explain ImportError. What is ModuleNotFoundError?

Ans-ImportError is a built-in exception in Python that is raised when an import statement fails
to import a module. This error occurs when Python is unable to locate and load the specified 
module in the current working directory or in the directories listed in the Python path.
For example, suppose we have a Python script example.py that imports the math module:
import math
print(math.pi)
2)ModuleNotFoundError is a subclass of ImportError.It is raised when Python is unable to locate
the specified module in the current working directory or in any of the directories listed in the
Python path.
Q6. List down some best practices for exception handling in python.

Ans-Here are some best practices for exception handling in Python:
1)Be specific
2)Use multiple except blocks
3)Use finally blocks
4)Use the with statement
'''
