# %%
'''Q1)What is an Exception in python? Write the difference between Exceptions and Syntax errors

Ans-In Python, an Exception is a runtime error that occurs when a program encounters a
situation that it cannot handle. When an Exception is raised, it means that something 
unexpected has happened during the execution of the program. Some common examples of Exceptions
in Python include:
1)TypeError: raised when an operation or function is applied to an object of inappropriate type
ValueError: raised when a function argument or parameter has an invalid value
NameError: raised when a name (variable, function, module, etc.) is not found in the current 
scope
2)ZeroDivisionError: raised when attempting to divide by zero
In contrast, Syntax errors are errors that occur when the Python interpreter is unable to parse
and interpret the code due to incorrect syntax. This usually means that there is a mistake in
the code that prevents it from being executed. Some common examples of Syntax errors include:
Missing parentheses, brackets or quotes
Misspelled keywords or variables
Improper indentation
The main difference between Exceptions and Syntax errors is that Syntax errors are caught by
the Python interpreter before the program is executed, while Exceptions occur during runtime 
and are typically caused by unexpected input or other issues that could not have been 
anticipated at the time the program was written. Syntax errors are typically easier to fix 
than Exceptions, since the Python interpreter can often provide helpful error messages that
point to the location of the error in the code. Exceptions, on the other hand, require more
careful handling and may require more advanced debugging techniques to identify and resolve.

Q2)What happens when an exception is not handled? Explain withan example

Ans-When an Exception is not handled in Python, it causes the program to terminate abruptly and 
display an error message or traceback. This can be problematic if the Exception occurs in the
middle of an important task or if it is not handled properly, since it can leave the program in
an unpredictable or unstable state.
Here's an example to illustrate what happens when an Exception is not handled:
def divide(x, y):
    return x/y

# This line will raise a ZeroDivisionError if y = 0
result = divide(10, 0)

print(result)

Q3. Which Python statements are used to catch and handle exceptions? Explain with an example

Ans-In Python, the try and except statements are used to catch and handle Exceptions.

The try statement is used to enclose the code block that may raise an Exception. If an
Exception is raised within the try block, the program will stop executing the try block and 
jump to the nearest except block that matches the type of the Exception that was raised.

The except statement is used to define the Exception that the block will handle, along with the
code that should be executed in response to the Exception. If the Exception that was raised
matches the type of the except block, then the code within the except block will be executed.
Here's an example to illustrate how to use try and except statements to handle Exceptions:
try:
    x = int(input("Please enter a number: "))
    y = 10 / x
    print(f"10 divided by {x} is {y}")
except ZeroDivisionError:
    print("Error: division by zero")
except ValueError:
    print("Error: invalid input")

Q4. Explain with an example
1)Try and Else-try and else are two keywords in Python that are used together in exception 
handling.The try statement is used to enclose the code block that may raise an Exception. If an 
Exception is raised within the try block, the program will stop executing the try block and
jump to the nearest except block that matches the type of the Exception that was raised.
On the other hand, the else statement is used in conjunction with try and except blocks to 
define a block of code that should be executed if no Exception is raised in the try block. 
The code in the else block will only execute if the try block completes without raising an 
Exception.

2)finally-finally is a keyword in Python that is used in conjunction with a try and except 
block to define a block of code that should be executed regardless of whether an Exception is
raised or not.
3)raise-raise is a keyword in Python that is used to explicitly raise an Exception. We can use 
the raise keyword to raise built-in or custom Exception types in our code.

Q5.What are Custom Exceptions in python? Why do we need Custom Ex,eptions? Explain withan 
example

Ans-Custom Exceptions in Python are user-defined Exception classes that allow us to define and
raise custom error messages in our code. We use custom Exceptions when we need to raise an 
error that is not covered by any of the built-in Exceptions in Python.
The primary benefit of using custom Exceptions is that they allow us to provide more meaningful
and specific error messages to help us debug and understand our code better. Additionally, 
custom Exceptions can be organized and categorized in a way that makes it easier to identify 
and handle different types of errors in our code.

Here's an example of how to define and use a custom Exception class in Python:
class InvalidInputError(Exception):

    def __init__(self, input_value):
        self.input_value = input_value
        self.message = f"Invalid input value: {input_value}"
        super().__init__(self.message)

def calculate_square_root(num):
    if num < 0:
        raise InvalidInputError(num)
    else:
        return num ** 0.5
        
Q6.Create a custom exception class.Use this class to handlean exception.       

Ans-class NegativeNumberError(Exception):
    """Exception raised for negative numbers"""

    def __init__(self, num):
        self.num = num
        self.message = f"Negative number {num} not allowed"
        super().__init__(self.message)

def square_root(num):
    if num < 0:
        raise NegativeNumberError(num)
    else:
        return num ** 0.5

try:
    print(square_root(4))
    print(square_root(-4))
except NegativeNumberError as e:
    print(e.message)
'''
