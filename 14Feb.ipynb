# %%
'''Q1) What is multithreading in python?Why is it used? Name the module used to handle
threads in python
Ans-1)Multithreading is a programming technique that allows a program to perform multiple 
tasks concurrently within a single process. In Python, multithreading can be achieved using
the threading module.
2)Multithreading in Python is used to improve the performance of programs by allowing them 
to perform multiple tasks simultaneously, making better use of system resources such as CPU
and memory. It can also be used to create responsive user interfaces, where long-running 
tasks are executed in the background, while the main thread handles user input and displays
updates.
3)To handle threads in Python, the threading module is used. This module provides a simple 
way to create and manage threads, with methods for starting and stopping threads, waiting 
for them to finish, and synchronizing their execution. 

Q2)Why threading module used? Write the use of the following functions
 1)activeCount()
 2)currentThread()
 3)enumerate()

Ans-The threading module in Python is used to implement multithreading in Python programs. 
Multithreading allows a program to perform multiple tasks concurrently within a single 
process, which can improve program performance by utilizing system resources such as CPU
and memory more efficiently.
1)activeCount() is a method provided by the threading module in Python that returns the 
number of Thread objects that are currently active in the current Python interpreter.
An active thread is a thread that has been started and has not yet finished executing or 
terminated.
2)currentThread() is a method provided by the threading module in Python that returns the
Thread object representing the current thread of execution. This method can be called from
within any thread to obtain a reference to the Thread object that represents that thread.
3)enumerate() is a built-in function in Python that can be used to iterate over a sequence
of elements while keeping track of the element's index. The function takes an iterable as
its argument and returns an iterator that generates pairs consisting of the index and the 
corresponding element.

Q3)Explain the following functions

Ans- 1)In Python, run() is a method provided by the Thread class in the threading module. This
method is used to start a new thread of execution by calling the run() method of the target
function or method provided when the Thread object was created.
2)In Python, start() is a method provided by the Thread class in the threading module. 
This method is used to start a new thread of execution by creating a new system thread and 
alling the run() method of the target function or method provided when the Thread object was
created.
3)In Python, join() is a method provided by the Thread class in the threading module. 
This method is used to wait for a thread to complete its execution and return before 
continuing with the rest of the program.
4)In Python, isAlive() is a method provided by the Thread class in the threading module.
This method is used to check whether a thread is currently executing or not.

Q5)State advantages and disadvantages of multithreading

Ans-Advantages of Multithreading:

Improved Performance: Multithreading allows the execution of multiple threads concurrently,
which can lead to improved performance and better utilization of available resources such as
CPU and memory.

Faster Response Time: By allowing multiple threads to execute concurrently, multithreading
can reduce the response time of an application, which is particularly important in real-time
systems.

Better Resource Management: Multithreading enables efficient use of system resources, such 
as memory and I/O devices, by allowing multiple threads to share these resources.

Enhanced User Experience: Multithreading can improve the user experience of an application
by enabling it to perform background tasks while the user interacts with the application.

Easier Code Maintenance: By dividing a complex task into smaller, more manageable threads,
multithreading can make code easier to maintain and debug.

Disadvantages of Multithreading:

Increased Complexity: Multithreading introduces additional complexity into an application,
which can make it more difficult to develop and debug.

Increased Overhead: Creating and managing multiple threads can result in increased overhead
, which can reduce performance.

Synchronization Issues: When multiple threads share resources, such as memory, there can be
synchronization issues that must be carefully managed to avoid data corruption and other
problems.

Difficulty in Debugging: Debugging multithreaded applications can be difficult, especially
when there are synchronization issues or race conditions.

Thread Safety: Developers must ensure that their code is thread-safe, which can require 
additional effort and testing.

Q6)Explain deadlocks and race conditions.

Ans-

'''
