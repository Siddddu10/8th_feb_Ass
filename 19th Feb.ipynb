# %%
'''Q1. What is Flask Framework? What are the advantages of Flask Framework?

Ans-Flask is a micro web framework written in Python that allows developers to quickly build 
web applications with minimal setup and boilerplate code. It is a lightweight framework that is
easy to learn and has a low barrier to entry, making it a popular choice for small to medium-sized
web applications and APIs.

Advantages of Flask Framework:

Lightweight: Flask is a lightweight framework that does not require many dependencies or
additional libraries to get started. This makes it easy to learn and use, especially for
beginners.

Easy to use: Flask has a simple and intuitive API that is easy to use. It provides a wide range
of built-in tools and utilities that simplify common web development tasks.

Flexibility: Flask provides developers with a lot of flexibility and freedom when it comes to 
designing and structuring their applications. It allows developers to choose their own database,
templating engine, and other components, giving them complete control over their application 
stack.

Extensibility: Flask is highly extensible and allows developers to easily integrate with other 
Python libraries and frameworks. This makes it easy to add new features and functionality to
your application as needed.

Testing: Flask provides built-in support for testing, making it easy to write and execute unit
tests and integration tests for your application.

Scalability: Flask is scalable and can be used to build applications of any size, from small
prototypes to large-scale web applications. It also supports multiple concurrent requests, 
making it ideal for building web APIs.

Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the 
output in Jupyter Notebook.

Ans-from flask import Flask

app = Flask(__name__)

@app.route('/')
def hello_world():
    return 'Hello World!!'

if __name__ == '__main__':
    app.run()

Q3. What is App routing in Flask? Why do we use app routes?

Ans-App routing is a feature in Flask that allows developers to map URLs to specific Python 
functions, also known as view functions. In other words, app routing is the mechanism that 
Flask uses to determine what code should be executed when a user requests a specific URL
We use app routes in Flask to define the structure of our web application and to determine how 
users will navigate through it. By defining different routes for different pages, we can make 
our application more organized and easier to use.

'''Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a
“/”route to show the following details:
Company Name: ABC Corporation
Location: India
Contact Detail: 999-999-9999
Attach the screenshot of the output in Jupyter Notebook.

Ans-

'''Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the
working of the url_for() function.

Ans-In Flask, the url_for() function is used for URL building. It takes the name of a view
function as its first argument, and any additional keyword arguments as parameters to generate 
a URL that maps to that function.
Here's an example:
from flask import Flask, url_for

app = Flask(__name__)

@app.route('/')
def index():
    return 'Hello, World!'

@app.route('/user/<username>')
def profile(username):
    return f'Hello, {username}!'

if __name__ == '__main__':
    with app.test_request_context():
        print(url_for('index'))
        print(url_for('profile', username='john'))

'''
